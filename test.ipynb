# %%
from quanta import state, units, operators
from quanta.mathematics import i
import numpy as np

# %%
spin_state = state.PureState(np.array([1.0, 0.0]), ["up", "down"])
spin_state
# Out:
# PureState(data=array([1., 0.]), basis=['up', 'down'])

# %%
spin_state.normalized
# Out:
# PureState(data=array([1., 0.]), basis=['up', 'down'])

# %%
spin_state.expectation(operators.pauli_z)
# Out:
# np.float64(1.0)
